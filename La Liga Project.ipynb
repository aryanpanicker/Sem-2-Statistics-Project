# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel(r"C:\Users\Aryan\Desktop\Stats Project\La Liga Training Data.xlsx")
data.head()
# Out:
#     Season             Team  MP   W   D   L   GF  GA  GD  POSS  PASS  \
# 0  2015-16    Athletic Club  38  18   8  12   58  45  13  49.9  74.4
# 1  2015-16  Atletico Madrid  38  28   4   6   63  18  45  48.5  77.9
# 2  2015-16        Barcelona  38  29   4   5  112  29  83  67.1  86.8
# 3  2015-16            Betis  38  11  12  15   34  52 -18  46.7  74.6
# 4  2015-16       Celta Vigo  38  17   9  12   51  59  -8  56.4  79.5
#
#    Shot On Target  SAVE  Points
# 0            35.7  70.2      62
# 1            34.7  82.8      88
# 2            44.0  78.1      91
# 3            31.7  72.0      45
# 4            35.0  63.9      60

# %%
data.describe()
# Out:
#           MP           W          D          L        GF          GA  \
# count  100.0  100.000000  100.00000  100.00000  100.0000  100.000000
# mean    38.0   14.180000    9.64000   14.18000   51.1000   51.100000
# std      0.0    6.020806    2.86575    5.61272   18.1378   13.942523
# min     38.0    4.000000    2.00000    1.00000   24.0000   18.000000
# 25%     38.0   10.000000    8.00000   12.00000   40.0000   43.000000
# 50%     38.0   13.000000    9.50000   14.00000   46.5000   50.500000
# 75%     38.0   18.000000   11.00000   18.00000   56.0000   60.250000
# max     38.0   29.000000   18.00000   28.00000  116.0000   94.000000
#
#                GD        POSS        PASS  Shot On Target        SAVE  \
# count  100.000000  100.000000  100.000000      100.000000  100.000000
# mean     0.000000   50.037000   76.759000       34.786000   70.091000
# std     27.377274    6.265887    6.085271        3.761528    5.886967
# ...

# %%
data.drop(['MP'],axis=1,inplace=True)
corr=data.corr()
corr.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_6989d_row0_col0, #T_6989d_row1_col1, #T_6989d_row2_col2, #T_6989d_row3_col3, #T_6989d_row4_col4, #T_6989d_row5_col5, #T_6989d_row6_col6, #T_6989d_row7_col7, #T_6989d_row8_col8, #T_6989d_row9_col9, #T_6989d_row10_col10 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6989d_row0_col1, #T_6989d_row2_col0, #T_6989d_row2_col3, #T_6989d_row2_col5, #T_6989d_row2_col6, #T_6989d_row2_col7, #T_6989d_row2_col8, #T_6989d_row2_col10, #T_6989d_row4_col9, #T_6989d_row5_col4, #T_6989d_row9_col4, #T_6989d_row10_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_6989d_row0_col2, #T_6989d_row0_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_6989d_row0_col3, #T_6989d_row3_col10, #T_6989d_row4_col2 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_6989d_row0_col5, #T_6989d_row5_col0 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_6989d_row0_col6, #T_6989d_row6_col8 {
#   background-color: #2a924a;
# ...

# %%
data.plot(kind="scatter",x="GF", y="Points", figsize=(5,5))
#plt.plot(data.GF,data.Points)
# Out:
# <AxesSubplot:xlabel='GF', ylabel='Points'>

# %%
data.plot(kind="scatter",x="GA", y="Points", figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='GA', ylabel='Points'>

# %%
data.plot(kind="scatter",x="POSS", y="Points", figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='POSS', ylabel='Points'>

# %%
data.plot(kind="scatter",x="PASS", y="Points", figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='PASS', ylabel='Points'>

# %%
data.plot(kind="scatter",x="Shot On Target", y="Points", figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='Shot On Target', ylabel='Points'>

# %%
data.plot(kind="scatter",x="SAVE", y="Points", figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='SAVE', ylabel='Points'>

# %%
X=data[['GF','GA','POSS','PASS','Shot On Target','SAVE']]
y=data['Points']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     GF  GA  POSS  PASS  Shot On Target  SAVE
# 8   46  69  44.6  73.2            30.4  62.2
# 65  53  62  51.7  80.5            35.8  65.6
# 85  37  49  51.9  79.8            36.6  68.8
# 31  36  55  44.7  71.3            32.8  64.2
# 90  30  51  43.8  71.8            33.5  66.2
# ..  ..  ..   ...   ...             ...   ...
# 94  70  25  59.1  85.4            40.2  78.7
# 20  41  43  44.4  76.4            34.5  75.0
# 71  37  43  42.8  71.8            31.4  69.0
# 49  50  59  46.8  73.8            33.0  68.0
# 55  94  44  60.5  85.5            38.5  70.4
#
# [80 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predictions=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9283863500783852

# %%
test_predictions
# Out:
# array([57.906806  , 46.61974688, 37.68473474, 37.99086681, 59.625208  ,
#        88.38066472, 18.17224099, 42.6040226 , 33.05634114, 61.42188353,
#        41.75384366, 41.83536459, 68.37815386, 54.8760018 , 47.47092219,
#        33.7900457 , 36.94618513, 49.79297463, 50.90343057, 67.61415776])

# %%
df=pd.read_excel(r"C:\Users\Aryan\Desktop\Stats Project\La Liga Test Data.xlsx")
df.head()
# Out:
#     Season             Team  MP   W   D   L  GF  GA  GD  POSS  PASS  \
# 0  2020-21           Alaves  38   9  11  18  36  57 -21  42.7  72.6
# 1  2020-21    Athletic Club  38  11  13  14  46  42   4  49.8  77.5
# 2  2020-21  Atletico Madrid  38  26   8   4  67  25  42  52.4  82.1
# 3  2020-21        Barcelona  38  24   7   7  85  38  47  65.8  89.1
# 4  2020-21            Betis  38  17  10  11  50  50   0  53.9  81.6
#
#    SHOT on TARGET  SAVE  Pts  Predicted Pts  Residual  Position  \
# 0            29.4  62.2   38             39        -1        16
# 1            32.9  65.4   46             52        -6        10
# 2            39.6  80.0   86             83         3         1
# 3            39.8  73.2   79             83        -4         3
# 4            33.0  66.4   61             50        11         6
#
#    Pred Position  Res Pos
# 0             15        1
# 1              8        2
# 2              3       -2
# 3              2        1
# 4              9       -3

# %%
X=df[['GF','GA','POSS','PASS','SHOT on TARGET','SAVE']]
y=df['Pts']

# %%
y_prediction=model.predict(X)
y_prediction
# Out:
# array([39.21635786, 55.59367386, 78.33837956, 80.17769284, 52.40253969,
#        38.34128619, 51.90906727, 39.2374889 , 40.18180504, 44.04202223,
#        40.22809904, 41.66927588, 45.32936575, 45.63463963, 74.51623196,
#        65.43244159, 64.6178021 , 49.5395796 , 38.14569533, 62.61646776])

# %%
model.score(X,y)
# Out:
# 0.8538458260890924

# %%
plt.figure(figsize=(26,5))
plt.scatter(df['Team'],y)
plt.scatter(df['Team'],y_prediction)
plt.xlabel("Teams")
plt.ylabel("Points")
plt.title("Actual Points vs Predicted Points")
plt.legend(["Actual",'Predicted'], loc=0)

# %%
plt.figure(figsize=(26,5))
plt.scatter(df['Team'],df['Position'])
plt.scatter(df['Team'],df['Pred Position'])
plt.xlabel("Teams")
plt.ylabel("Points")
plt.title("Actual Position vs Predicted Position")
plt.legend(["Actual",'Predicted'], loc=0)
